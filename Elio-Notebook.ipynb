# %% [markdown]
# # Tree Data Set

# %% [markdown]
# If you have ever taken a dog on a walk, then you know that they love smelling all kinds of different trees.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

info = pd.read_csv("trees.csv")
df = pd.DataFrame(info)
df.groupby('neighborhood').count()
# Out:
# /opt/tljh/user/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                       id  address_number  street  common_name  \
# neighborhood
# Allegheny Center     867              21      21          867
# Allegheny West       386             250     250          386
# Allentown             84              84      84           84
# Arlington            107             107     107          107
# Arlington Heights      5               5       5            5
# ...                  ...             ...     ...          ...
# Upper Lawrenceville  373             373     373          373
# West End             131             131     131          131
# West Oakland          78              78      78           78
# Westwood             260             258     258          260
# Windgap              117             109     109          110
#
#                      scientific_name  height  width  growth_space_length  \
# neighborhood
# Allegheny Center                 867     865    865                  865
# Allegheny West                   386     370    370                  370
# Allentown                         84      66     66                   66
# Arlington                        107      94     94                   94
# Arlington Heights                  5       5      5                    5
# ...                              ...     ...    ...                  ...
# Upper Lawrenceville              373     332    332                  332
# West End                         131     119    118                  118
# West Oakland                      78      71     71                   71
# Westwood                         260     251    251                  251
# Windgap                          110     103    103                  103
#
#                      growth_space_width  growth_space_type  ...  \
# neighborhood                                                ...
# Allegheny Center                    865                867  ...
# Allegheny West                      370                386  ...
# Allentown                            66                 84  ...
# Arlington                            94                107  ...
# Arlington Heights                     5                  5  ...
# ...                                 ...                ...  ...
# Upper Lawrenceville                 332                373  ...
# West End                            118                131  ...
# West Oakland                         71                 78  ...
# Westwood                            251                258  ...
# Windgap                             103                109  ...
#
#                      overall_benefits_dollar_value  council_district  ward  \
# neighborhood
# Allegheny Center                               861               867   867
# Allegheny West                                 368               386   386
# Allentown                                       60                84    84
# Arlington                                       82               107   107
# Arlington Heights                                4                 5     5
# ...                                            ...               ...   ...
# Upper Lawrenceville                            322               373   373
# West End                                       111               131   131
# West Oakland                                    71                78    78
# Westwood                                       247               260   260
# Windgap                                        102               117   117
#
#                      tract  public_works_division  pli_division  police_zone  \
# neighborhood
# Allegheny Center       867                    867           867          867
# Allegheny West         386                    386           386          386
# Allentown               84                     84            84           84
# Arlington              107                    107           107          107
# Arlington Heights        5                      5             5            5
# ...                    ...                    ...           ...          ...
# Upper Lawrenceville    373                    373           373          373
# West End               131                    131           131          131
# West Oakland            78                     78            78           78
# Westwood               260                    260           260          260
# Windgap                117                    117           117          117
#
#                      fire_zone  latitude  longitude
# neighborhood
# Allegheny Center           867       867        867
# Allegheny West             386       386        386
# Allentown                   84        84         84
# Arlington                  107       107        107
# Arlington Heights            5         5          5
# ...                        ...       ...        ...
# Upper Lawrenceville        373       373        373
# West End                   131       131        131
# West Oakland                78        78         78
# Westwood                   260       260        260
# Windgap                    117       117        117
#
# [90 rows x 57 columns]

# %% [markdown]
# The csv file gives a list of trees without telling you how many trees each neighborhood has. Therefore, I had to group the trees by neighborhoods to see how many trees each neighborhood has.

# %% [markdown]
# # But

# %% [markdown]
# grouping the trees by neighborhoods wasn't enough because some trees are in a resedential, commercial, or industrial properties. Accordingly, I only take a look at the different kinds of trees in parks based on the neighborhood since we don't want to trespass.

# %%
park_mask = info["land_use"]== "Park"
parks = info[park_mask]

parks["neighborhood"].value_counts()
# Out:
# Central Business District    128
# Highland Park                124
# South Side Flats             104
# Bedford Dwellings             64
# Polish Hill                   48
# Squirrel Hill South           38
# Bloomfield                    37
# East Liberty                  32
# Central Oakland               29
# Strip District                23
# Point Breeze                  23
# Point Breeze North            22
# Larimer                       21
# Brighton Heights              20
# South Oakland                 20
# Spring Hill-City View         18
# North Shore                   18
# North Oakland                 17
# Shadyside                     17
# Banksville                    16
# Marshall-Shadeland            16
# Upper Hill                    15
# Terrace Village               15
# Greenfield                    15
# Manchester                    14
# Lower Lawrenceville           12
# Duquesne Heights              11
# Perry North                   11
# Homewood North                 8
# Homewood South                 8
# Beechview                      7
# Stanton Heights                6
# Lincoln-Lemington-Belmar       6
# Middle Hill                    5
# Allegheny West                 4
# Swisshelm Park                 4
# Hazelwood                      4
# Perry South                    4
# California-Kirkbride           4
# New Homestead                  3
# Troy Hill                      3
# Sheraden                       3
# Brookline                      2
# Garfield                       2
# Morningside                    2
# Allentown                      2
# Bon Air                        2
# Overbrook                      1
# Carrick                        1
# Central Northside              1
# West Oakland                   1
# Allegheny Center               1
# East Allegheny                 1
# Name: neighborhood, dtype: int64

# %%
parks["neighborhood"].value_counts().head(15).plot(kind='bar', figsize=(15,5))

# %%
parks["neighborhood"].value_counts().head(13).plot(kind='pie', figsize=(15,5))
